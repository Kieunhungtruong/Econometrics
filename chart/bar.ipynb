# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("/content/drive/MyDrive/econometrics/rawdata/grade.xlsx")
df
# Out:
#     grade  frequency
# 0     0.0         14
# 1     0.2          0
# 2     0.4          1
# 3     0.6          6
# 4     0.8         12
# 5     1.0         43
# 6     1.2        126
# 7     1.4        278
# 8     1.6        619
# 9     1.8       1156
# 10    2.0       1975
# 11    2.2       2935
# 12    2.4       4279
# 13    2.6       5682
# 14    2.8       7304
# 15    3.0       8593
# 16    3.2      10076
# 17    3.4      11770
# 18    3.6      13026
# 19    3.8      14851
# 20    4.0      16457
# 21    4.2      17680
# 22    4.4      19896
# 23    4.6      21858
# 24    4.8      24293
# 25    5.0      26556
# 26    5.2      28625
# 27    5.4      31312
# 28    5.6      34541
# 29    5.8      37440
# 30    6.0      40256
# 31    6.2      43554
# 32    6.4      46501
# 33    6.6      49310
# 34    6.8      51590
# 35    7.0      53000
# 36    7.2      54349
# 37    7.4      55274
# 38    7.6      56019
# 39    7.8      55990
# 40    8.0      54184
# 41    8.2      48784
# 42    8.4      39798
# 43    8.6      27884
# 44    8.8      16048
# 45    9.0       7573
# 46    9.2       2899
# 47    9.4        962
# 48    9.6        221
# 49    9.8         43
# 50   10.0          0

# %%
plt.bar(df["grade"].astype(str), df["frequency"], width=0.6)
plt.xticks(fontsize=3.5)
plt.show()
