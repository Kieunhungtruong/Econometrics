# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
#!pip install pyreadstat
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import pyreadstat

# %%
df, meta = pyreadstat.read_dta ("/content/drive/MyDrive/econometrics/rawdata/migration_remittances_16_full.dta",encoding ='latin1')

# %%
plt.hist(df["per_expenditure"], bins=27, color='gray', edgecolor='black')
plt.title("Histogram of Per Capita Expenditure", fontsize=16)
plt.xlabel("Per Capita Expenditure", fontsize=13)
plt.ylabel("Frequency", fontsize=13)
plt.show()
